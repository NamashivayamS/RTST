# %% [markdown]
# # RTST Research Environment Setup
#
# This notebook serves as the entry point for configuring and bootstrapping the Kaggle GPU environment for the **Real-Time Speech Translator (RTST)** research framework.
#
# ### Purpose
# - Prepares the environment by running the modular bootstrap process.
# - Synchronizes the codebase with GitHub.
# - Installs Kaggle-specific dependencies.
# - Prepares hardware (GPU/VRAM) checks.

# %% [markdown]
# ## Step 1: Run the Bootstrap Script

# %%
import os
import sys

# Ensure project root is in system path
project_root = os.path.abspath(os.path.join(os.getcwd(), '../../..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from research.kaggle.scripts.bootstrap import setup_environment
setup_environment()
